# %%
# 라이이브러러리 사용
import tensorflow as tf
import pandas as pd

# %%
# 데이터 준비
파일경로 = 'https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/lemonade.csv'
레모네이드 = pd.read_csv(파일경로)
레모네이드.head()
# Out:
#    온도  판매량
# 0  20   40
# 1  21   42
# 2  22   44
# 3  23   46
# 4  24   48

# %%
# 종속변수 ,독립변수
독립 = 레모네이드[['온도']]
종속 = 레모네이드[['판매량']]
print(독립.shape, 종속.shape)
# Out:
# (6, 1) (6, 1)

# %%
# 모델을 만듭니다.
X = tf.keras.layers.Input(shape=[1])
Y = tf.keras.layers.Dense(1)(X)
model = tf.keras.models.Model(X, Y)
model.compile(loss='mse')

# %%
# 모델을 학습합니다.
model.fit(독립, 종속, epochs=10)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4040e-04
# Epoch 2/10
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4045e-04
# Epoch 3/10
# 1/1 [==============================] - 0s 3ms/step - loss: 1.4049e-04
# Epoch 4/10
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4046e-04
# Epoch 5/10
# 1/1 [==============================] - 0s 4ms/step - loss: 1.4038e-04
# Epoch 6/10
# 1/1 [==============================] - 0s 3ms/step - loss: 1.4036e-04
# Epoch 7/10
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4043e-04
# Epoch 8/10
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4039e-04
# Epoch 9/10
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4030e-04
# Epoch 10/10
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4031e-04

# %%
# 모델을 이용합니다.
model.predict(독립)
# Out:
# array([[40.012424],
#        [42.012188],
#        [44.011955],
#        [46.011723],
#        [48.01149 ],
#        [50.011257]], dtype=float32)

# %%
model.predict([[15]])
# Out:
# array([[30.013588]], dtype=float32)
